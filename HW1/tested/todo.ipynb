# %%
#put your colab link here:
#https://colab.research.google.com/drive/16j9Ngl7fEo1ViJUsDontM4FEDtGSyXT3?usp=sharing

# %%
from TodoClient import TodoClient

dburl = "https://dsci-dbd03-default-rtdb.firebaseio.com/tasks"


todo = TodoClient(dburl)
todo.clear()
# Out:
# {'error': '404 Not Found'}

# %%
from TodoClient import TodoClient

# dburl = "https://dsci-dbd02-default-rtdb.firebaseio.com/tasks"
# change it to your own database url:
dburl = "https://fir-96e2f-default-rtdb.firebaseio.com/tasks"

todo = TodoClient(dburl)

todo.clear()
# Out:
# "Success!"

# %%
todo.delete_task('watch movie')
# Out:
# "Error in delete_task: task "watch movie" does not exist!"

# %%
todo.add_task('watch movie')
# Out:
# "Success!"

# %%
todo.get_all_tasks()
# Out:
# {'watch movie': 'pending'}

# %%
todo.mark_completed('watch movie')
# Out:
# "Success!"

# %%
todo.add_task('complete hw1')
# Out:
# "Success!"

# %%
todo.get_task_by_status('pending')
# Out:
# ['complete hw1']

# %%
todo.get_all_tasks()
# Out:
# {'complete hw1': 'pending', 'watch movie': 'completed'}

# %%
todo.mark_completed('complete hw1')
# Out:
# "Success!"

# %%
todo.get_task_by_status('pending')
# Out:
# []

# %%
todo.add_task('watch movie')
# Out:
# "Error in add_task: task "watch movie" already exists!"

# %%
todo.delete_task('watch movie')
# Out:
# "Success!"

# %%
todo.get_all_tasks()
# Out:
# {'complete hw1': 'completed'}

# %%
todo.delete_task('complete hw1')
# Out:
# "Success!"

# %%
todo.get_all_tasks()
# Out:
# None

# %%
todo.get_task_by_status('pending')
# Out:
# []

# %%
todo.mark_completed('complete hw1')
# Out:
# "Error in mark_completed: task "complete hw1" does not exist!"

# %%
todo.add_task('go to school')
# Out:
# "Success!"

# %%
todo.add_task('go to work')
# Out:
# "Success!"

# %%
todo.get_task_by_status('pending')
# Out:
# ['go to school', 'go to work']

# %%
todo.get_task_by_status('completed')
# Out:
# []

# %%
todo.mark_completed('go to school')
# Out:
# "Success!"

# %%
todo.get_task_by_status('completed')
# Out:
# ['go to school']

# %%
todo.get_all_tasks()
# Out:
# {'go to school': 'completed', 'go to work': 'pending'}

# %%
todo.clear()
# Out:
# "Success!"

# %%
todo.get_all_tasks()
# Out:
# None

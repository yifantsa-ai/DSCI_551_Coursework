# %%
#https://colab.research.google.com/drive/1kSDlKhO1-P_VIK8b_tGcGdFbY262FZ1L?usp=sharing

# %%
from filesystem import FileSystem
from hw2session import HW2Session

fs = FileSystem()
fs.format()

fs.add_user('john')
fs.add_user('david')

session = HW2Session(fs)
session.login('david')

while True:
  user_input = input(f'{session.user_name}@usc:{session.pwd()}$ ')

  if (user_input == 'exit'):
    break

  args = user_input.split()
  n_args = len(args)

  if (n_args == 0):
    continue

  cmd = args[0]

  if cmd == 'ls':
    res = session.ls()
    if res is not None:
      print(res)
  elif cmd == 'pwd':
    if n_args != 1:
      print('invalid input!')
    else:
      print(session.pwd())
  elif cmd == 'mkdir':
    if n_args != 2:
      print('invalid input!')
    else:
      session.mkdir(args[1])
  elif cmd == 'rmdir':
    if n_args != 2:
      print('invalid input!')
    else:
      session.rmdir(args[1])
  elif cmd == 'cd':
    if n_args == 1: # just cd
      session.cd()
    elif n_args == 2:
      session.cd(args[1])
    else:
      print('invalid input!')
  elif cmd == 'touch':
    if n_args == 2:
      session.touch(args[1])
    else:
      print('invalid input!')
  elif cmd == 'rm':
    if n_args == 2:
      session.rm(args[1])
    else:
      print('invalid input!')
  else:
    print('unknown command!')

session.dump_fsimage()
# Out:
# david@usc:/home/david$ rm file1
# file1 does not exist!
# david@usc:/home/david$ rmdir dir1
# dir1 does not exist!
# david@usc:/home/david$ mkdir dsci551
# david@usc:/home/david$ ls
# dsci551(directory)
# david@usc:/home/david$ cd dsci551
# david@usc:/home/david/dsci551$ pwd
# /home/david/dsci551
# david@usc:/home/david/dsci551$ touch Faker
# david@usc:/home/david/dsci551$ ls
# Faker(file)
# david@usc:/home/david/dsci551$ rm Faker
# david@usc:/home/david/dsci551$ ls
# david@usc:/home/david/dsci551$ touch hw1
# david@usc:/home/david/dsci551$ ls
# hw1(file)
# david@usc:/home/david/dsci551$ mkdir data
# david@usc:/home/david/dsci551$ ls
# hw1(file) data(directory)
# david@usc:/home/david/dsci551$ rm data
# data is not a file!
# david@usc:/home/david/dsci551$ ls
# hw1(file) data(directory)
# david@usc:/home/david/dsci551$ rmdir data
# david@usc:/home/david/dsci551$ ls
# hw1(file)
# david@usc:/home/david/dsci551$ rmdir hw1
# hw1 is not a directory!
# david@usc:/home/david/dsci551$ cd ..
# david@usc:/home/david$ rmdir dsci551
# dsci551 is not empty!
# david@usc:/home/david$ ls
# dsci551(directory)
# david@usc:/home/david$ cd dsci551
# david@usc:/home/david/dsci551$ mkdir data1
# david@usc:/home/david/dsci551$ cd data1
# david@usc:/home/david/dsci551/data1$ touch blackhole.csv
# david@usc:/home/david/dsci551/data1$ ls
# blackhole.csv(file)
# david@usc:/home/david/dsci551/data1$ cd ..
# david@usc:/home/david/dsci551$ ls
# hw1(file) data1(directory)
# david@usc:/home/david/dsci551$ cd ..
# david@usc:/home/david$ mkdir dsci552
# david@usc:/home/david$ rmdir dsci553
# dsci553 does not exist!
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory)
# david@usc:/home/david$ mkdir dsci553
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory) dsci553(directory)
# david@usc:/home/david$ rm dsci553
# dsci553 is not a file!
# david@usc:/home/david$ rmdir dsci553
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory)
# david@usc:/home/david$ cd dsci552
# david@usc:/home/david/dsci552$ touch linear
# david@usc:/home/david/dsci552$ mkdir regression
# david@usc:/home/david/dsci552$ ls
# linear(file) regression(directory)
# david@usc:/home/david/dsci552$ cd regression
# david@usc:/home/david/dsci552/regression$ touch class
# david@usc:/home/david/dsci552/regression$ mkdir github
# david@usc:/home/david/dsci552/regression$ ls
# class(file) github(directory)
# david@usc:/home/david/dsci552/regression$ cd
# david@usc:/home/david$ rmdir dsci552
# dsci552 is not empty!
# david@usc:/home/david$ rm dsci553
# dsci553 does not exist!
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory)
# david@usc:/home/david$ mkdir dsci553
# david@usc:/home/david$ rm dsci553
# dsci553 is not a file!
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory) dsci553(directory)
# david@usc:/home/david$ touch dsci554
# david@usc:/home/david$ touch dsci555
# david@usc:/home/david$ mkdir dsci556
# david@usc:/home/david$ ls
# dsci551(directory) dsci552(directory) dsci553(directory) dsci554(file) dsci555(file) dsci556(directory)
# david@usc:/home/david$ cd dsci556
# david@usc:/home/david/dsci556$ mkdir transcript
# david@usc:/home/david/dsci556$ cd transcript
# david@usc:/home/david/dsci556/transcript$ mkdir camera
# david@usc:/home/david/dsci556/transcript$ ls
# camera(directory)
# david@usc:/home/david/dsci556/transcript$ cd
# david@usc:/home/david$ exit
# /,directory
# /home,directory
# /home/john,directory
# /home/david,directory
# /home/david/dsci551,directory
# /home/david/dsci551/hw1,file
# /home/david/dsci551/data1,directory
# /home/david/dsci551/data1/blackhole.csv,file
# /home/david/dsci552,directory
# /home/david/dsci552/linear,file
# /home/david/dsci552/regression,directory
# /home/david/dsci552/regression/class,file
# /home/david/dsci552/regression/github,directory
# /home/david/dsci553,directory
# /home/david/dsci554,file
# /home/david/dsci555,file
# /home/david/dsci556,directory
# /home/david/dsci556/transcript,directory
# /home/david/dsci556/transcript/camera,directory
